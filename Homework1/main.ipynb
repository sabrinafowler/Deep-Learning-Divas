# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns
import math

# load data
DATA_DIR = './tensorflow-datasets/'

# training data = 90% of train set, validation = 10% of train set
# test set predefined on import
# shuffle to prevent ordering
train_ds = tfds.load('fashion_mnist', split='train[:90%]', data_dir=DATA_DIR, shuffle_files=True)
val_ds = tfds.load('fashion_mnist', split='train[-10%:]', data_dir=DATA_DIR, shuffle_files=True)
test_ds = tfds.load('fashion_mnist', split='test', data_dir=DATA_DIR, shuffle_files=True)


# preprocessing function
def preprocess(sample):
    
    # cast to float (will normalize to 0-1 scale in model)
    image = tf.cast(sample['image'], tf.float32)
    
     # one-hot encode labels for use of softmax/probabilty distribution
    label = tf.one_hot(sample['label'], depth=10)
    
    return image, label

# 32 standard batch size
BATCH_SIZE = 32

# apply preprocessing + batching
# shuffle training set to eliminate accidental ordering in batches
train_ds = train_ds.map(preprocess).shuffle(10000).batch(BATCH_SIZE)
val_ds = val_ds.map(preprocess).batch(BATCH_SIZE)
test_ds = test_ds.map(preprocess).batch(BATCH_SIZE)


# general build model function
def build_model(layers=[128], learning_rate=0.001, use_regularizer=False):
    model = tf.keras.Sequential()
    
    # normalize to 0-1 scale
    model.add(tf.keras.layers.Rescaling(1./255, input_shape=(28,28,1)))
    
    # flatten vector
    model.add(tf.keras.layers.Flatten())

    # regularize with L2 (penalize excessively large weights, but keep all features)
    if use_regularizer:
        reg = tf.keras.regularizers.l2(0.001)
    else:
        reg = None
    
    # add hidden layers
    for layer in layers:
        model.add(tf.keras.layers.Dense(layer, activation="relu", kernel_regularizer=reg))
    
    # softmax output layer
    model.add(tf.keras.layers.Dense(10, activation="softmax"))

    # compile model with Adam
    # categorical crossentropy used with one-hot encoded labels
    # track accuracy
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        loss="categorical_crossentropy",
        metrics=["accuracy"]
    )
    
    return model


# train and evaluate
def train_and_evaluate(layers, lr, use_reg, model_name):
    
    print(f"\n***** Training {model_name} *****")
    
    # compile model with given architecture
    model = build_model(layers, learning_rate=lr, use_regularizer=use_reg)
    
    # early stopping
    early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

    # train model
    # also collect loss/ accuracy cuvres
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=20,
        verbose=2,
        callbacks=[early_stop]
    )
    
    val_loss, val_acc = model.evaluate(val_ds, verbose=0)
    print(f"{run_name} Validation Accuracy: {val_acc:.4f}")
    
    test_loss, test_acc = model.evaluate(test_ds, verbose=0)
    print(f"{run_name} Test Accuracy: {test_acc:.4f}")
    
    # confusion matrices
    y_pred_probs = model.predict(test_ds)
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_true = np.concatenate([np.argmax(y.numpy(), axis=1) for x, y in test_ds], axis=0)
 
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8,6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title(f'Confusion Matrix: {run_name}')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()
    
    # confidence intervals
    n_test = len(y_true)
    p_error = 1 - test_acc
    # caculates 95% confidence interval
    ci = 1.96 * math.sqrt(p_error * (1 - p_error) / n_test)
    print(f"Generalization error: {p_error:.3f} ± {ci:.3f} (95% CI)")
    
    return model, history


# hidden layers
architectures = [[128], [256, 128]]

# learning rates
learning_rates = [0.001, 0.0005] 

# regularizer?
regularizers = [False, True]

# store model objects
results = {}

# run 8 total experiments
for arch in architectures:
    for lr in learning_rates:
        for reg in regularizers:
            
            run_name = f"Architecture: {arch}, Learning rate: {lr}, Regularize: {reg}"
            model, history = train_and_evaluate(arch, lr, reg, run_name)
            results[run_name] = model

# evaluate on test set
print("\n***** Test Set Evaluation *****")
for run_name, model in results.items():
    test_loss, test_acc = model.evaluate(test_ds, verbose=0)
    print(f"{run_name} Test Accuracy: {test_acc:.4f}")
# Out:
# ***** Training Architecture: [128], Learning rate: 0.001, Regularize: False *****
# Epoch 1/20
# 1688/1688 - 5s - loss: 0.5104 - accuracy: 0.8203 - val_loss: 0.3877 - val_accuracy: 0.8647
# Epoch 2/20
# 1688/1688 - 3s - loss: 0.3837 - accuracy: 0.8613 - val_loss: 0.3657 - val_accuracy: 0.8685
# Epoch 3/20
# 1688/1688 - 3s - loss: 0.3447 - accuracy: 0.8759 - val_loss: 0.3436 - val_accuracy: 0.8740
# Epoch 4/20
# 1688/1688 - 3s - loss: 0.3209 - accuracy: 0.8828 - val_loss: 0.3201 - val_accuracy: 0.8843
# Epoch 5/20
# 1688/1688 - 3s - loss: 0.3013 - accuracy: 0.8888 - val_loss: 0.3154 - val_accuracy: 0.8852
# Epoch 6/20
# 1688/1688 - 3s - loss: 0.2864 - accuracy: 0.8947 - val_loss: 0.3111 - val_accuracy: 0.8883
# Epoch 7/20
# 1688/1688 - 3s - loss: 0.2725 - accuracy: 0.8987 - val_loss: 0.3078 - val_accuracy: 0.8868
# Epoch 8/20
# 1688/1688 - 3s - loss: 0.2624 - accuracy: 0.9031 - val_loss: 0.3247 - val_accuracy: 0.8843
# Epoch 9/20
# 1688/1688 - 3s - loss: 0.2526 - accuracy: 0.9067 - val_loss: 0.3159 - val_accuracy: 0.8840
# Epoch 10/20
# 1688/1688 - 3s - loss: 0.2427 - accuracy: 0.9099 - val_loss: 0.2909 - val_accuracy: 0.8938
# Epoch 11/20
# 1688/1688 - 3s - loss: 0.2357 - accuracy: 0.9126 - val_loss: 0.2933 - val_accuracy: 0.8942
# Epoch 12/20
# 1688/1688 - 3s - loss: 0.2261 - accuracy: 0.9159 - val_loss: 0.2992 - val_accuracy: 0.8927
# Epoch 13/20
# 1688/1688 - 3s - loss: 0.2194 - accuracy: 0.9191 - val_loss: 0.2996 - val_accuracy: 0.8928
# Architecture: [128], Learning rate: 0.001, Regularize: False Validation Accuracy: 0.8938
# Architecture: [128], Learning rate: 0.001, Regularize: False Test Accuracy: 0.8832
# Generalization error: 0.117 ± 0.006 (95% CI)
#
# ***** Training Architecture: [128], Learning rate: 0.001, Regularize: True *****
# Epoch 1/20
# 1688/1688 - 3s - loss: 0.6595 - accuracy: 0.8140 - val_loss: 0.5259 - val_accuracy: 0.8443
# Epoch 2/20
# 1688/1688 - 3s - loss: 0.5157 - accuracy: 0.8469 - val_loss: 0.4881 - val_accuracy: 0.8567
# Epoch 3/20
# 1688/1688 - 3s - loss: 0.4843 - accuracy: 0.8556 - val_loss: 0.5142 - val_accuracy: 0.8387
# Epoch 4/20
# 1688/1688 - 3s - loss: 0.4664 - accuracy: 0.8599 - val_loss: 0.4509 - val_accuracy: 0.8725
# Epoch 5/20
# 1688/1688 - 3s - loss: 0.4546 - accuracy: 0.8622 - val_loss: 0.4802 - val_accuracy: 0.8510
# Epoch 6/20
# 1688/1688 - 3s - loss: 0.4433 - accuracy: 0.8656 - val_loss: 0.4296 - val_accuracy: 0.8710
# Epoch 7/20
# 1688/1688 - 3s - loss: 0.4365 - accuracy: 0.8658 - val_loss: 0.4487 - val_accuracy: 0.8622
# Epoch 8/20
# 1688/1688 - 3s - loss: 0.4317 - accuracy: 0.8683 - val_loss: 0.4282 - val_accuracy: 0.8707
# Epoch 9/20
# 1688/1688 - 3s - loss: 0.4264 - accuracy: 0.8709 - val_loss: 0.4193 - val_accuracy: 0.8757
# Epoch 10/20
# 1688/1688 - 3s - loss: 0.4214 - accuracy: 0.8718 - val_loss: 0.4301 - val_accuracy: 0.8710
# Epoch 11/20
# 1688/1688 - 3s - loss: 0.4175 - accuracy: 0.8740 - val_loss: 0.4325 - val_accuracy: 0.8743
# Epoch 12/20
# 1688/1688 - 3s - loss: 0.4159 - accuracy: 0.8731 - val_loss: 0.4066 - val_accuracy: 0.8800
# Epoch 13/20
# 1688/1688 - 3s - loss: 0.4134 - accuracy: 0.8745 - val_loss: 0.4132 - val_accuracy: 0.8753
# Epoch 14/20
# 1688/1688 - 3s - loss: 0.4116 - accuracy: 0.8746 - val_loss: 0.4267 - val_accuracy: 0.8688
# Epoch 15/20
# 1688/1688 - 3s - loss: 0.4086 - accuracy: 0.8753 - val_loss: 0.4201 - val_accuracy: 0.8700
# Architecture: [128], Learning rate: 0.001, Regularize: True Validation Accuracy: 0.8800
# Architecture: [128], Learning rate: 0.001, Regularize: True Test Accuracy: 0.8675
# Generalization error: 0.132 ± 0.007 (95% CI)
#
# ***** Training Architecture: [128], Learning rate: 0.0005, Regularize: False *****
# Epoch 1/20
# 1688/1688 - 3s - loss: 0.5314 - accuracy: 0.8172 - val_loss: 0.4136 - val_accuracy: 0.8545
# Epoch 2/20
# 1688/1688 - 3s - loss: 0.4007 - accuracy: 0.8593 - val_loss: 0.3894 - val_accuracy: 0.8672
# Epoch 3/20
# 1688/1688 - 3s - loss: 0.3580 - accuracy: 0.8714 - val_loss: 0.3380 - val_accuracy: 0.8783
# Epoch 4/20
# 1688/1688 - 3s - loss: 0.3309 - accuracy: 0.8799 - val_loss: 0.3357 - val_accuracy: 0.8795
# Epoch 5/20
# 1688/1688 - 3s - loss: 0.3111 - accuracy: 0.8870 - val_loss: 0.3168 - val_accuracy: 0.8837
# Epoch 6/20
# 1688/1688 - 3s - loss: 0.2985 - accuracy: 0.8921 - val_loss: 0.3054 - val_accuracy: 0.8905
# Epoch 7/20
# 1688/1688 - 3s - loss: 0.2836 - accuracy: 0.8957 - val_loss: 0.3097 - val_accuracy: 0.8870
# Epoch 8/20
# 1688/1688 - 3s - loss: 0.2737 - accuracy: 0.8987 - val_loss: 0.2945 - val_accuracy: 0.8923
# Epoch 9/20
# 1688/1688 - 3s - loss: 0.2612 - accuracy: 0.9047 - val_loss: 0.2991 - val_accuracy: 0.8892
# Epoch 10/20
# 1688/1688 - 3s - loss: 0.2543 - accuracy: 0.9057 - val_loss: 0.2911 - val_accuracy: 0.8927
# Epoch 11/20
# 1688/1688 - 3s - loss: 0.2433 - accuracy: 0.9107 - val_loss: 0.3025 - val_accuracy: 0.8898
# Epoch 12/20
# 1688/1688 - 3s - loss: 0.2361 - accuracy: 0.9133 - val_loss: 0.2870 - val_accuracy: 0.8948
# Epoch 13/20
# 1688/1688 - 3s - loss: 0.2290 - accuracy: 0.9155 - val_loss: 0.2961 - val_accuracy: 0.8952
# Epoch 14/20
# 1688/1688 - 3s - loss: 0.2221 - accuracy: 0.9174 - val_loss: 0.2741 - val_accuracy: 0.9010
# Epoch 15/20
# 1688/1688 - 3s - loss: 0.2163 - accuracy: 0.9204 - val_loss: 0.2995 - val_accuracy: 0.8880
# Epoch 16/20
# 1688/1688 - 3s - loss: 0.2102 - accuracy: 0.9231 - val_loss: 0.2962 - val_accuracy: 0.8953
# Epoch 17/20
# 1688/1688 - 3s - loss: 0.2040 - accuracy: 0.9244 - val_loss: 0.2937 - val_accuracy: 0.8977
# Architecture: [128], Learning rate: 0.0005, Regularize: False Validation Accuracy: 0.9010
# Architecture: [128], Learning rate: 0.0005, Regularize: False Test Accuracy: 0.8840
# Generalization error: 0.116 ± 0.006 (95% CI)
#
# ***** Training Architecture: [128], Learning rate: 0.0005, Regularize: True *****
# Epoch 1/20
# 1688/1688 - 3s - loss: 0.7018 - accuracy: 0.8134 - val_loss: 0.5516 - val_accuracy: 0.8542
# Epoch 2/20
# 1688/1688 - 3s - loss: 0.5304 - accuracy: 0.8507 - val_loss: 0.5005 - val_accuracy: 0.8567
# Epoch 3/20
# 1688/1688 - 3s - loss: 0.4825 - accuracy: 0.8607 - val_loss: 0.4642 - val_accuracy: 0.8698
# Epoch 4/20
# 1688/1688 - 3s - loss: 0.4511 - accuracy: 0.8676 - val_loss: 0.4457 - val_accuracy: 0.8718
# Epoch 5/20
# 1688/1688 - 3s - loss: 0.4347 - accuracy: 0.8688 - val_loss: 0.4573 - val_accuracy: 0.8555
# Epoch 6/20
# 1688/1688 - 3s - loss: 0.4217 - accuracy: 0.8724 - val_loss: 0.4203 - val_accuracy: 0.8715
# Epoch 7/20
# 1688/1688 - 3s - loss: 0.4123 - accuracy: 0.8754 - val_loss: 0.4172 - val_accuracy: 0.8697
# Epoch 8/20
# 1688/1688 - 3s - loss: 0.4071 - accuracy: 0.8756 - val_loss: 0.3973 - val_accuracy: 0.8820
# Epoch 9/20
# 1688/1688 - 3s - loss: 0.3979 - accuracy: 0.8795 - val_loss: 0.4135 - val_accuracy: 0.8720
# Epoch 10/20
# 1688/1688 - 3s - loss: 0.3933 - accuracy: 0.8813 - val_loss: 0.4054 - val_accuracy: 0.8753
# Epoch 11/20
# 1688/1688 - 3s - loss: 0.3900 - accuracy: 0.8811 - val_loss: 0.3966 - val_accuracy: 0.8787
# Epoch 12/20
# 1688/1688 - 3s - loss: 0.3875 - accuracy: 0.8824 - val_loss: 0.3877 - val_accuracy: 0.8873
# Epoch 13/20
# 1688/1688 - 3s - loss: 0.3811 - accuracy: 0.8845 - val_loss: 0.4063 - val_accuracy: 0.8747
# Epoch 14/20
# 1688/1688 - 3s - loss: 0.3765 - accuracy: 0.8860 - val_loss: 0.3946 - val_accuracy: 0.8832
# Epoch 15/20
# 1688/1688 - 3s - loss: 0.3744 - accuracy: 0.8871 - val_loss: 0.3956 - val_accuracy: 0.8788
# Architecture: [128], Learning rate: 0.0005, Regularize: True Validation Accuracy: 0.8873
# Architecture: [128], Learning rate: 0.0005, Regularize: True Test Accuracy: 0.8695
# Generalization error: 0.131 ± 0.007 (95% CI)
#
# ***** Training Architecture: [256, 128], Learning rate: 0.001, Regularize: False *****
# Epoch 1/20
# 1688/1688 - 3s - loss: 0.4868 - accuracy: 0.8242 - val_loss: 0.4070 - val_accuracy: 0.8502
# Epoch 2/20
# 1688/1688 - 3s - loss: 0.3676 - accuracy: 0.8645 - val_loss: 0.3709 - val_accuracy: 0.8617
# Epoch 3/20
# 1688/1688 - 3s - loss: 0.3293 - accuracy: 0.8790 - val_loss: 0.3441 - val_accuracy: 0.8718
# Epoch 4/20
# 1688/1688 - 3s - loss: 0.3049 - accuracy: 0.8873 - val_loss: 0.3289 - val_accuracy: 0.8773
# Epoch 5/20
# 1688/1688 - 3s - loss: 0.2899 - accuracy: 0.8928 - val_loss: 0.3042 - val_accuracy: 0.8852
# Epoch 6/20
# 1688/1688 - 3s - loss: 0.2733 - accuracy: 0.8980 - val_loss: 0.3358 - val_accuracy: 0.8803
# Epoch 7/20
# 1688/1688 - 3s - loss: 0.2583 - accuracy: 0.9031 - val_loss: 0.2997 - val_accuracy: 0.8932
# Epoch 8/20
# 1688/1688 - 3s - loss: 0.2472 - accuracy: 0.9079 - val_loss: 0.2934 - val_accuracy: 0.8940
# Epoch 9/20
# 1688/1688 - 3s - loss: 0.2376 - accuracy: 0.9096 - val_loss: 0.3005 - val_accuracy: 0.8918
# Epoch 10/20
# 1688/1688 - 3s - loss: 0.2283 - accuracy: 0.9145 - val_loss: 0.3023 - val_accuracy: 0.8908
# Epoch 11/20
# 1688/1688 - 3s - loss: 0.2184 - accuracy: 0.9168 - val_loss: 0.3534 - val_accuracy: 0.8812
# Architecture: [256, 128], Learning rate: 0.001, Regularize: False Validation Accuracy: 0.8940
# Architecture: [256, 128], Learning rate: 0.001, Regularize: False Test Accuracy: 0.8840
# Generalization error: 0.116 ± 0.006 (95% CI)
#
# ***** Training Architecture: [256, 128], Learning rate: 0.001, Regularize: True *****
# Epoch 1/20
# 1688/1688 - 4s - loss: 0.7588 - accuracy: 0.8163 - val_loss: 0.5931 - val_accuracy: 0.8338
# Epoch 2/20
# 1688/1688 - 4s - loss: 0.5502 - accuracy: 0.8467 - val_loss: 0.5235 - val_accuracy: 0.8503
# Epoch 3/20
# 1688/1688 - 4s - loss: 0.4995 - accuracy: 0.8552 - val_loss: 0.4864 - val_accuracy: 0.8578
# Epoch 4/20
# 1688/1688 - 4s - loss: 0.4712 - accuracy: 0.8615 - val_loss: 0.4549 - val_accuracy: 0.8665
# Epoch 5/20
# 1688/1688 - 4s - loss: 0.4530 - accuracy: 0.8642 - val_loss: 0.4676 - val_accuracy: 0.8605
# Epoch 6/20
# 1688/1688 - 4s - loss: 0.4352 - accuracy: 0.8694 - val_loss: 0.4228 - val_accuracy: 0.8740
# Epoch 7/20
# 1688/1688 - 4s - loss: 0.4283 - accuracy: 0.8717 - val_loss: 0.4082 - val_accuracy: 0.8735
# Epoch 8/20
# 1688/1688 - 4s - loss: 0.4212 - accuracy: 0.8731 - val_loss: 0.4234 - val_accuracy: 0.8715
# Epoch 9/20
# 1688/1688 - 4s - loss: 0.4156 - accuracy: 0.8750 - val_loss: 0.4012 - val_accuracy: 0.8802
# Epoch 10/20
# 1688/1688 - 4s - loss: 0.4106 - accuracy: 0.8762 - val_loss: 0.4075 - val_accuracy: 0.8778
# Epoch 11/20
# 1688/1688 - 4s - loss: 0.4066 - accuracy: 0.8765 - val_loss: 0.4275 - val_accuracy: 0.8672
# Epoch 12/20
# 1688/1688 - 4s - loss: 0.4022 - accuracy: 0.8776 - val_loss: 0.4381 - val_accuracy: 0.8637
# Architecture: [256, 128], Learning rate: 0.001, Regularize: True Validation Accuracy: 0.8802
# Architecture: [256, 128], Learning rate: 0.001, Regularize: True Test Accuracy: 0.8669
# Generalization error: 0.133 ± 0.007 (95% CI)
#
# ***** Training Architecture: [256, 128], Learning rate: 0.0005, Regularize: False *****
# Epoch 1/20
# 1688/1688 - 3s - loss: 0.5022 - accuracy: 0.8232 - val_loss: 0.3867 - val_accuracy: 0.8580
# Epoch 2/20
# 1688/1688 - 3s - loss: 0.3642 - accuracy: 0.8677 - val_loss: 0.3662 - val_accuracy: 0.8653
# Epoch 3/20
# 1688/1688 - 3s - loss: 0.3270 - accuracy: 0.8799 - val_loss: 0.3212 - val_accuracy: 0.8838
# Epoch 4/20
# 1688/1688 - 3s - loss: 0.3026 - accuracy: 0.8880 - val_loss: 0.3057 - val_accuracy: 0.8870
# Epoch 5/20
# 1688/1688 - 3s - loss: 0.2836 - accuracy: 0.8951 - val_loss: 0.2964 - val_accuracy: 0.8883
# Epoch 6/20
# 1688/1688 - 3s - loss: 0.2662 - accuracy: 0.9015 - val_loss: 0.3082 - val_accuracy: 0.8892
# Epoch 7/20
# 1688/1688 - 3s - loss: 0.2530 - accuracy: 0.9049 - val_loss: 0.2938 - val_accuracy: 0.8957
# Epoch 8/20
# 1688/1688 - 3s - loss: 0.2400 - accuracy: 0.9097 - val_loss: 0.3059 - val_accuracy: 0.8883
# Epoch 9/20
# 1688/1688 - 3s - loss: 0.2272 - accuracy: 0.9150 - val_loss: 0.3059 - val_accuracy: 0.8933
# Epoch 10/20
# 1688/1688 - 3s - loss: 0.2203 - accuracy: 0.9165 - val_loss: 0.2905 - val_accuracy: 0.8953
# Epoch 11/20
# 1688/1688 - 3s - loss: 0.2078 - accuracy: 0.9216 - val_loss: 0.2993 - val_accuracy: 0.8912
# Epoch 12/20
# 1688/1688 - 3s - loss: 0.2013 - accuracy: 0.9246 - val_loss: 0.2983 - val_accuracy: 0.8943
# Epoch 13/20
# 1688/1688 - 3s - loss: 0.1917 - accuracy: 0.9280 - val_loss: 0.3159 - val_accuracy: 0.8930
# Architecture: [256, 128], Learning rate: 0.0005, Regularize: False Validation Accuracy: 0.8953
# Architecture: [256, 128], Learning rate: 0.0005, Regularize: False Test Accuracy: 0.8877
# Generalization error: 0.112 ± 0.006 (95% CI)
#
# ***** Training Architecture: [256, 128], Learning rate: 0.0005, Regularize: True *****
# Epoch 1/20
# 1688/1688 - 4s - loss: 0.8266 - accuracy: 0.8190 - val_loss: 0.6552 - val_accuracy: 0.8490
# Epoch 2/20
# 1688/1688 - 4s - loss: 0.5882 - accuracy: 0.8542 - val_loss: 0.5240 - val_accuracy: 0.8687
# Epoch 3/20
# 1688/1688 - 4s - loss: 0.5148 - accuracy: 0.8631 - val_loss: 0.5025 - val_accuracy: 0.8622
# Epoch 4/20
# 1688/1688 - 4s - loss: 0.4734 - accuracy: 0.8682 - val_loss: 0.4693 - val_accuracy: 0.8675
# Epoch 5/20
# 1688/1688 - 4s - loss: 0.4467 - accuracy: 0.8736 - val_loss: 0.4412 - val_accuracy: 0.8725
# Epoch 6/20
# 1688/1688 - 4s - loss: 0.4296 - accuracy: 0.8764 - val_loss: 0.4390 - val_accuracy: 0.8675
# Epoch 7/20
# 1688/1688 - 4s - loss: 0.4158 - accuracy: 0.8793 - val_loss: 0.4181 - val_accuracy: 0.8740
# Epoch 8/20
# 1688/1688 - 4s - loss: 0.4070 - accuracy: 0.8811 - val_loss: 0.3958 - val_accuracy: 0.8868
# Epoch 9/20
# 1688/1688 - 4s - loss: 0.3991 - accuracy: 0.8823 - val_loss: 0.3964 - val_accuracy: 0.8832
# Epoch 10/20
# 1688/1688 - 4s - loss: 0.3920 - accuracy: 0.8848 - val_loss: 0.3978 - val_accuracy: 0.8813
# Epoch 11/20
# 1688/1688 - 4s - loss: 0.3860 - accuracy: 0.8863 - val_loss: 0.4046 - val_accuracy: 0.8812
# Architecture: [256, 128], Learning rate: 0.0005, Regularize: True Validation Accuracy: 0.8868
# Architecture: [256, 128], Learning rate: 0.0005, Regularize: True Test Accuracy: 0.8716
# Generalization error: 0.128 ± 0.007 (95% CI)
#
# ***** Test Set Evaluation *****
# Architecture: [128], Learning rate: 0.001, Regularize: False Test Accuracy: 0.8832
# Architecture: [128], Learning rate: 0.001, Regularize: True Test Accuracy: 0.8675
# Architecture: [128], Learning rate: 0.0005, Regularize: False Test Accuracy: 0.8840
# Architecture: [128], Learning rate: 0.0005, Regularize: True Test Accuracy: 0.8695
# Architecture: [256, 128], Learning rate: 0.001, Regularize: False Test Accuracy: 0.8840
# Architecture: [256, 128], Learning rate: 0.001, Regularize: True Test Accuracy: 0.8669
# Architecture: [256, 128], Learning rate: 0.0005, Regularize: False Test Accuracy: 0.8877
# Architecture: [256, 128], Learning rate: 0.0005, Regularize: True Test Accuracy: 0.8716
